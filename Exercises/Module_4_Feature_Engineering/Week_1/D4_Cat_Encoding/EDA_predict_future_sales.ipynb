# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import glob
from googletrans import Translator

# %%
path = r'C:\Users\Amash\Projects\Strive\Exercises\Module_4_Feature_Engineering\Week_1\D3_Num_Encoding\data'

# %%
files = glob.glob(path + '\*.csv')

# %%
dfs = []
for file in files:
    df_name = file[98:-4]
    dfs.append(df_name)
    vars()[file[98:-4]] = pd.read_csv(file)

# %%
path_translated = r'C:\Users\Amash\Projects\Strive\Exercises\Module_4_Feature_Engineering\Week_1\D4_Cat_Encoding\data\translated'

# %%
files_translated = glob.glob(path_translated + '\*.csv')

# %%
for file in files_translated:
    df_name = file[109:-4]
    dfs.append(df_name)
    vars()[file[109:-4]] = pd.read_csv(file)

# %%
items_merged = items_translated.merge(items, on='item_id').drop('item_name', axis=1)

# %%
sales_train.merge(items, on='item_id', how='left').merge(item_categories, on='item_category_id', how='left').merge(shops, on='shop_id', how='left')
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# ...

# %%
df_full = sales_train.merge(items_merged, on='item_id', how='left').merge(shops_translated, on='shop_id', how='left').merge(item_categories_translated, on='item_category_id', how='left')

# %%
df_full['date'] = pd.to_datetime(df_full['date'])

# %%
df_full.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154      999.00           1.0
# 1 2013-03-01               0       25     2552      899.00           1.0
# 2 2013-05-01               0       25     2552      899.00          -1.0
# 3 2013-06-01               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
#
#                        item_name_translated  item_category_id  \
# 0                           SCENE 2012 (BD)                37
# 1  DEEP PURPLE  The House Of Blue Light  LP                58
# 2  DEEP PURPLE  The House Of Blue Light  LP                58
# 3  DEEP PURPLE  Who Do You Think We Are  LP                58
# 4   DEEP PURPLE 30 Very Best Of 2CD (Фирм.)                56
#
#                  shop_name_translated     item_category_name_translated
# 0  Yaroslavl Shopping center "Altair"                  Cinema - Blu-Ray
# ...

# %%
df_full.plot('date', 'item_price')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_full.plot('date', 'item_cnt_day')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_full.set_index('date', inplace=True)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2935849 entries, 2013-02-01 to 2015-03-10
# Data columns (total 9 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   date_block_num                 int64
#  1   shop_id                        int64
#  2   item_id                        int64
#  3   item_price                     float64
#  4   item_cnt_day                   float64
#  5   item_name_translated           object
#  6   item_category_id               int64
#  7   shop_name_translated           object
#  8   item_category_name_translated  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 224.0+ MB

# %%
df_full['item_cnt_day'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_full.head()
# Out:
#             date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# date
# 2013-02-01               0       59    22154      999.00           1.0
# 2013-03-01               0       25     2552      899.00           1.0
# 2013-05-01               0       25     2552      899.00          -1.0
# 2013-06-01               0       25     2554     1709.05           1.0
# 2013-01-15               0       25     2555     1099.00           1.0
#
#                                 item_name_translated  item_category_id  \
# date
# 2013-02-01                           SCENE 2012 (BD)                37
# 2013-03-01  DEEP PURPLE  The House Of Blue Light  LP                58
# 2013-05-01  DEEP PURPLE  The House Of Blue Light  LP                58
# 2013-06-01  DEEP PURPLE  Who Do You Think We Are  LP                58
# 2013-01-15   DEEP PURPLE 30 Very Best Of 2CD (Фирм.)                56
#
#                           shop_name_translated  \
# date
# ...

# %%
d = df_full.resample('Q')#.rest_index()

# %%
d['item_cnt_day'].sum().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
d['item_price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sales = pd.DataFrame()

# Select data for each year and concatenate with prices here 
for year in ['2013', '2014', '2015']:
    sales_per_year = df_full.loc[year, ['item_cnt_day']].reset_index(drop=True)
    sales_per_year.rename(columns={'item_cnt_day': year}, inplace=True)
    sales = pd.concat([sales, sales_per_year], axis=1)

# %%
# Plot prices
sales.plot()
plt.show()

# %%
df_full['item_cnt_day'].pct_change(periods=360).mul(100).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_full.resample('M').ffill()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-9169c808d67b> in <module>
# ----> 1 df_full.resample('M').ffill()
#
# ~\anaconda3\envs\Strive\lib\site-packages\pandas\core\resample.py in pad(self, limit)
#     471         DataFrame.fillna: Fill NA/NaN values using the specified method.
#     472         """
# --> 473         return self._upsample("pad", limit=limit)
#     474
#     475     ffill = pad
#
# ~\anaconda3\envs\Strive\lib\site-packages\pandas\core\resample.py in _upsample(self, method, limit, fill_value)
#    1135             result.index = res_index
#    1136         else:
# -> 1137             result = obj.reindex(
#    1138                 res_index, method=method, limit=limit, fill_value=fill_value
#    1139             )
#
# ~\anaconda3\envs\Strive\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df_full.asfreq('M')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-6ba0cb698f50> in <module>
# ----> 1 df_full.asfreq('M')
#
# ~\anaconda3\envs\Strive\lib\site-packages\pandas\core\generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    7821         from pandas.core.resample import asfreq
#    7822
# -> 7823         return asfreq(
#    7824             self,
#    7825             freq,
#
# ~\anaconda3\envs\Strive\lib\site-packages\pandas\core\resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    1917         dti = date_range(obj.index[0], obj.index[-1], freq=freq)
#    1918         dti.name = obj.index.name
# -> 1919         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    1920         if normalize:
#    1921             new_obj.index = new_obj.index.normalize()
#
# ...
