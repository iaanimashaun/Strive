# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv(url)
df = pd.DataFrame(data)
df.plot(x='month_number', y="total_profit")
plt.xlabel("Month Name")
plt.ylabel("Total Profit")
plt.title("Company Profit by Month")
plt.show()

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
df.plot(x="month_number", y="total_profit", xlabel="Month Number", ylabel="Total Profit", marker='o', linestyle="--", colormap='autumn', figsize=(10,8))

plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(12,10))

for column in df.columns[1:7]:
    ax.plot(df['month_number'], df[column], label=column + 'sales data', marker='o', linewidth=5, markersize=12)


ax.set_ylim(500,18000)
ax.set_xlabel('Month', fontsize=18)
ax.set_ylabel('Sales Units in Number', fontsize=18)
ax.set_title('Sales Data', fontsize=24)
plt.legend(loc='upper left', fontsize=20)
plt.show()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
df.plot(x="month_number", y="toothpaste", kind="scatter", figsize=(10,10), grid=True)
plt.xlabel("Month Number")
plt.ylabel("Units of toothpaste sold")
plt.legend("Toothpaste units Sold")
plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
df.plot(x='month_number', y=["facecream", "facewash"], kind="bar")
plt.xticks(fontsize=14, rotation=360);

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
df.plot(x="month_number", y="bathingsoap", kind="bar", figsize=(10,8))
plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
df.plot(x="month_number", y="total_profit", kind="hist", figsize=(10,8))
plt.show()

# %%
df.tail()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
num = df.drop(['month_number','total_profit', 'total_units'], axis=1).sum(axis=0)
num
# Out:
# facecream       34480
# facewash        18515
# toothpaste      69910
# bathingsoap    114010
# shampoo         25410
# moisturizer     18515
# dtype: int64

# %%
denominator = df.drop(['month_number','total_profit', 'total_units'], axis=1).sum(axis=0).sum()
denominator
# Out:
# 280840

# %%
values = num/denominator*100
values
# Out:
# facecream      12.277453
# facewash        6.592722
# toothpaste     24.893178
# bathingsoap    40.596069
# shampoo         9.047856
# moisturizer     6.592722
# dtype: float64

# %%
autopct=lambda p: '{:.2f}%({:.0f})'

# %%
plt.pie(values, autopct='%.2f%%', radius=2, explode=[0,0,0,0.1,0,0], labels=df.columns[1:7]);
plt.legend(loc='lower right', bbox_to_anchor=(2.3, -0.3), fontsize=12);

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
df.head(3)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700

# %%
# Write your code here

plt.style.use('fivethirtyeight')

fig, (ax1, ax2) = plt.subplots(2,1, sharex=True, figsize=(12,8))

x = df['month_number']
y1 = df['bathingsoap']
y2 = df['facewash']
ax1.plot(x, y1, 'ko-')
ax1.set_title('Sales Data of Bathing Soap')
ax1.set_ylim(6000, 15000)
ax2.plot(x, y2, 'r-o')
ax2.set_title('Sales Data of Facewash')
ax2.set_ylim(1000, 2200)
ax2.set_xlabel('Month')
ax2.set_ylabel('Sales Units in Numbers')
ax2.set_xticks(range(1,13))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here


plt.stackplot(df['month_number'], df['facecream'], df['facewash'], df['toothpaste'], df['bathingsoap'],
              df['shampoo'], df['moisturizer'], labels=df.columns[1:7]);

plt.title('All Product Sales  Data Using Stacked Plot')
plt.xlabel('Month')
plt.ylabel('Amount of Sales Unit')

plt.legend(loc='upper left');
